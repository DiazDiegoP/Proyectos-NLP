# %% [markdown]
# # Punto 1: Pre-Procesamiento
#
# - `[18 pts]` Leer el archivo `Princesas.csv` usando `pandas` y crear una nueva columna con el texto en minúscula, sin caracteres especiales ni números, sin palabras vacias y hacer stemming de las palabras

# %% [markdown]
# - Importar librerias

# %%
import re
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
stopwords_sp = stopwords.words('spanish')

from nltk.stem.snowball import SnowballStemmer
spanishStemmer=SnowballStemmer("spanish") # carga de raices en español

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics.pairwise import euclidean_distances
import nltk

# %% [markdown]
# **1.1 Lectura archivo:**

# %%
# lectura de archivo
princesas = pd.read_csv('Princesas.csv', sep=',')
princesas.head()
# Out:
#        Princesa                                       Personalidad
# 0  Blancanieves  Blancanieves es una princesa de noble cuna que...
# 1    Cenicienta  Cenicienta es inicialmente una sirvienta en su...
# 2        Aurora  La Princesa Aurora, la Bella Durmiente, es la ...
# 3         Bella  Bella es una muchacha que vive en la campiña f...
# 4        Jasmín  Cuando se introdujo por primera vez, la Prince...

# %%
princesas.shape
# Out:
# (10, 2)

# %% [markdown]
# **1.2 texto en minúscula, sin caracteres especiales ni números, sin palabras vacias y con stemming:**

# %% [markdown]
# - Definición de funciones:

# %%
def quitar_tildes(s):
    tildes = (
        ("á", "a"),
        ("é", "e"),
        ("í", "i"),
        ("ó", "o"),
        ("ú", "u"),
    )
    for origen, destino in tildes:
        s = s.replace(origen, destino)
    return s

# %%
def Preprocesamiento(s):
    
    texto_min = s.lower() # minúsculas
    texto_l = re.sub(r"[\W\d_]+", " ",texto_min) # remove caract, números
    texto_sint = quitar_tildes(texto_l) # remove tildes
    texto_t = texto_sint.split() # tokenizar
    texto_stopW = [palabra for palabra in texto_t if palabra not in stopwords_sp] # stopwords
    texto_stem = [spanishStemmer.stem(palabra) for palabra in texto_stopW] # stemming
    texto_procesado = " ".join(texto_stem)
    
    return texto_procesado

# %% [markdown]
# - Creación de nueva columna con el pre-procesamiento:

# %%
princesas['pre-procesado'] = princesas['Personalidad'].apply(lambda comentario: Preprocesamiento(comentario))

# %%
princesas
# Out:
#        Princesa                                       Personalidad  \
# 0  Blancanieves  Blancanieves es una princesa de noble cuna que...
# 1    Cenicienta  Cenicienta es inicialmente una sirvienta en su...
# 2        Aurora  La Princesa Aurora, la Bella Durmiente, es la ...
# 3         Bella  Bella es una muchacha que vive en la campiña f...
# 4        Jasmín  Cuando se introdujo por primera vez, la Prince...
# 5    Pocahontas  El nombre de Pocahontas significa "Pequeña Sil...
# 6         Mulan  Mulan es atípica a los anteriores papeles feme...
# 7         Tiana  Es una joven camarera que sueña con ser dueña ...
# 8        Mérida  Mérida llama la atención por su característico...
# 9         Moana  Moana, una joven de 16 años de edad, hija únic...
#
#                                        pre-procesado
# 0  blancaniev princes nobl cun ve forz servidumbr...
# 1  cenicient inicial sirvient cas constant objet ...
# 2  princes auror bell durmient hij unic rein flor...
# 3  bell muchach viv campiñ frances padr inventor ...
# 4  introduj primer vez princes jasmin poc dias de...
# 5  nombr pocahont signif pequeñ silenci bas figur...
# 6  mul atip anterior papel femenin pelicul disney...
# 7  jov camarer sueñ ser dueñ propi restaur algun ...
# 8  mer llam atencion caracterist pel anaranj oscu...
# 9  moan jov años edad hij unic sucesor import jef...

# %% [markdown]
# # Punto 2: TF-IDF
#
# - `[16 pts]` Crear la matriz TF-IDF

# %% [markdown]
# **2.1 TF-IDF**

# %%
tfidf_vect = TfidfVectorizer()

tfidf = tfidf_vect.fit_transform(princesas['pre-procesado'].values)

tfidf_matrix = pd.DataFrame(tfidf.toarray(), index=princesas['Princesa'].values, columns=tfidf_vect.get_feature_names())

tfidf_matrix.T.round(3)
# Out:
#          Blancanieves  Cenicienta  Aurora  Bella  Jasmín  Pocahontas  Mulan  \
# abrum           0.000         0.0   0.065  0.000   0.000       0.000    0.0
# abuel           0.000         0.0   0.000  0.000   0.000       0.000    0.0
# acuerd          0.000         0.0   0.055  0.000   0.000       0.000    0.0
# adem            0.000         0.0   0.000  0.000   0.000       0.097    0.0
# afortun         0.087         0.0   0.000  0.000   0.000       0.000    0.0
# ...               ...         ...     ...    ...     ...         ...    ...
# viv             0.000         0.0   0.000  0.073   0.000       0.000    0.0
# volunt          0.000         0.0   0.000  0.000   0.163       0.000    0.0
# volv            0.000         0.0   0.065  0.000   0.000       0.000    0.0
# vudu            0.000         0.0   0.000  0.000   0.000       0.000    0.0
# wak             0.000         0.0   0.000  0.000   0.000       0.000    0.0
#
#          Tiana  Mérida  Moana
# abrum    0.000    0.00  0.000
# abuel    0.000    0.00  0.102
# acuerd   0.000    0.08  0.000
# adem     0.000    0.00  0.000
# afortun  0.000    0.00  0.000
# ...        ...     ...    ...
# viv      0.000    0.00  0.087
# volunt   0.000    0.00  0.000
# volv     0.000    0.00  0.000
# vudu     0.126    0.00  0.000
# wak      0.000    0.00  0.102
#
# [572 rows x 10 columns]

# %% [markdown]
# # Punto 3: Distancia del coseno
# - `[12 pts]` Calcular la distancia del coseno entre cada una de las princesas
# - `[2 pts]` ¿Cuáles son las princesas más parecidas?
# - `[2 pts]` ¿Cuáles son las princesas más diferentes?

# %% [markdown]
# **3.1 Calcular la distancia del coseno**

# %%
#tfidf_matrix

# %%
dist_cos = cosine_distances(tfidf_matrix.values)
dist_cos = pd.DataFrame(dist_cos, columns = princesas['Princesa'].values, index = princesas['Princesa'].values)
dist_cos
# Out:
#               Blancanieves  Cenicienta    Aurora     Bella    Jasmín  \
# Blancanieves      0.000000    0.846938  0.841187  0.921131  0.934530
# Cenicienta        0.846938    0.000000  0.855609  0.943221  0.958420
# Aurora            0.841187    0.855609  0.000000  0.816663  0.937056
# Bella             0.921131    0.943221  0.816663  0.000000  0.888784
# Jasmín            0.934530    0.958420  0.937056  0.888784  0.000000
# Pocahontas        0.920278    0.956574  0.865628  0.865305  0.943590
# Mulan             0.871945    0.933945  0.910840  0.879418  0.936092
# Tiana             0.961197    0.918273  0.919058  0.963203  0.935021
# Mérida            0.985196    0.970544  0.938931  0.947451  0.972123
# Moana             0.958144    0.974853  0.961817  0.907177  0.968945
#
#               Pocahontas     Mulan     Tiana    Mérida     Moana
# Blancanieves    0.920278  0.871945  0.961197  0.985196  0.958144
# Cenicienta      0.956574  0.933945  0.918273  0.970544  0.974853
# Aurora          0.865628  0.910840  0.919058  0.938931  0.961817
# Bella           0.865305  0.879418  0.963203  0.947451  0.907177
# Jasmín          0.943590  0.936092  0.935021  0.972123  0.968945
# Pocahontas      0.000000  0.877391  0.962937  0.963890  0.917242
# Mulan           0.877391  0.000000  0.980113  0.987560  0.947563
# Tiana           0.962937  0.980113  0.000000  0.978574  0.970780
# Mérida          0.963890  0.987560  0.978574  0.000000  0.965109
# Moana           0.917242  0.947563  0.970780  0.965109  0.000000

# %% [markdown]
# **3.2 ¿Cuales son las princesas mas parecidas?**

# %% [markdown]
# - Bella y Aurora, con $0.816663$
# - Aurora y Blancanieves, con $0.841187$

